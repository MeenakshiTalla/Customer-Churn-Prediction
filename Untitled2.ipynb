# %%
#import Libraries
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#Load the data
df = pd.read_csv("Churn-Data.csv")
df.sample(5)
# Out:
#              cID  gender  SeniorCitizen Partner Dependents  tenure  \
# 842   4032-RMHCI  Female              0     Yes        Yes      41
# 3301  8062-YBDOE    Male              1      No         No       1
# 5216  3082-WQRVY    Male              1     Yes         No      14
# 2929  7660-HDPJV  Female              0      No         No       1
# 1786  9391-DXGGG  Female              1      No         No      44
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 842            No  No phone service             DSL                  Yes  ...
# 3301          Yes                No     Fiber optic                   No  ...
# 5216          Yes                No              No  No internet service  ...
# 2929          Yes                No     Fiber optic                   No  ...
# 1786          Yes                No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport         TV_Streaming  \
# 842                   Yes                   No                   No
# 3301                   No                   No                   No
# 5216  No internet service  No internet service  No internet service
# 2929                   No                   No                   No
# 1786                  Yes                   No                   No
#
#           Movie_Streaming        Contract PaperlessBilling  \
# 842                    No        One year               No
# 3301                   No  Month-to-month              Yes
# 5216  No internet service        One year               No
# 2929                   No  Month-to-month              Yes
# 1786                  Yes        One year               No
#
#                Method_Payment Charges_Month  TotalCharges Churn
# 842   Credit card (automatic)         35.40        1412.4    No
# 3301         Electronic check         69.65         69.65   Yes
# 5216             Mailed check         19.65        228.65    No
# 2929         Electronic check         69.20          69.2   Yes
# 1786  Credit card (automatic)         89.15       3990.75    No
#
# [5 rows x 21 columns]

# %%
#First of all, drop customerID column as it is of no use
df.drop('cID',axis='columns',inplace=True)

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# TV_Streaming         object
# Movie_Streaming      object
# Contract             object
# PaperlessBilling     object
# Method_Payment       object
# Charges_Month       float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
#Quick glance at above makes me realize that TotalCharges should be float but it is an object. Let's check what's going on with this column
df.TotalCharges.values
# Out:
# array(['1336.8', '5129.45', '23.45', ..., '306.05', '1200.15', '457.3'],
#       dtype=object)

# %%
pd.to_numeric(df.TotalCharges,errors='coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 5629    False
# 5630    False
# 5631    False
# 5632    False
# 5633    False
# Name: TotalCharges, Length: 5634, dtype: bool

# %%
df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 4       Male              0      No        Yes       0          Yes
# 282   Female              0     Yes        Yes       0           No
# 2419    Male              0     Yes        Yes       0          Yes
# 2734    Male              0     Yes        Yes       0          Yes
# 2903    Male              0     Yes        Yes       0          Yes
# 3974  Female              0     Yes        Yes       0          Yes
# 5023    Male              0      No        Yes       0          Yes
# 5030  Female              0     Yes        Yes       0          Yes
# 5343  Female              0     Yes        Yes       0           No
# 5599    Male              0     Yes        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 4                  Yes             DSL                  Yes
# 282   No phone service             DSL                  Yes
# 2419               Yes              No  No internet service
# 2734                No              No  No internet service
# 2903                No              No  No internet service
# 3974                No             DSL                  Yes
# 5023                No              No  No internet service
# 5030                No              No  No internet service
# 5343  No phone service             DSL                  Yes
# 5599               Yes              No  No internet service
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 4                     Yes                   No                  Yes
# 282                   Yes                  Yes                  Yes
# 2419  No internet service  No internet service  No internet service
# 2734  No internet service  No internet service  No internet service
# 2903  No internet service  No internet service  No internet service
# 3974                  Yes                  Yes                   No
# 5023  No internet service  No internet service  No internet service
# 5030  No internet service  No internet service  No internet service
# 5343                   No                  Yes                  Yes
# 5599  No internet service  No internet service  No internet service
#
#              TV_Streaming      Movie_Streaming  Contract PaperlessBilling  \
# 4                      No                   No  Two year              Yes
# 282                   Yes                   No  Two year               No
# 2419  No internet service  No internet service  Two year               No
# 2734  No internet service  No internet service  One year              Yes
# 2903  No internet service  No internet service  Two year               No
# 3974                  Yes                  Yes  Two year               No
# 5023  No internet service  No internet service  Two year               No
# 5030  No internet service  No internet service  Two year               No
# 5343                  Yes                   No  Two year              Yes
# 5599  No internet service  No internet service  Two year               No
#
#                  Method_Payment  Charges_Month TotalCharges Churn
# 4     Bank transfer (automatic)          61.90                 No
# 282     Credit card (automatic)          56.05                 No
# 2419               Mailed check          25.35                 No
# 2734               Mailed check          19.70                 No
# 2903               Mailed check          19.85                 No
# 3974               Mailed check          80.85                 No
# 5023               Mailed check          20.25                 No
# 5030               Mailed check          20.00                 No
# 5343  Bank transfer (automatic)          52.55                 No
# 5599               Mailed check          25.75                 No

# %%
df.shape
# Out:
# (5634, 20)

# %%
df.iloc[488].TotalCharges
# Out:
# '655.5'

# %%
df[df.TotalCharges!=' '].shape
# Out:
# (5624, 20)

# %%
#Remove rows with space in TotalCharges
df1 = df[df.TotalCharges!=' ']
df1.shape
# Out:
# (5624, 20)

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# TV_Streaming         object
# Movie_Streaming      object
# Contract             object
# PaperlessBilling     object
# Method_Payment       object
# Charges_Month       float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df1.TotalCharges.values
# Out:
# array(['1336.8', '5129.45', '23.45', ..., '306.05', '1200.15', '457.3'],
#       dtype=object)

# %%
df1[df1.Churn=='No']
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0      No        Yes      21          Yes
# 1     Female              0      No         No      54          Yes
# 5       Male              0      No         No       7          Yes
# 6       Male              0     Yes        Yes      32          Yes
# 7       Male              0     Yes        Yes      72          Yes
# ...      ...            ...     ...        ...     ...          ...
# 5626  Female              0      No         No       2          Yes
# 5627    Male              0     Yes        Yes      72          Yes
# 5630  Female              0     Yes        Yes      23          Yes
# 5631    Male              0     Yes        Yes      12          Yes
# 5633    Male              0      No         No      26          Yes
#
#      MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0               No             DSL                  Yes                   No
# 1              Yes     Fiber optic                   No                  Yes
# 5               No     Fiber optic                   No                   No
# 6               No              No  No internet service  No internet service
# 7               No              No  No internet service  No internet service
# ...            ...             ...                  ...                  ...
# 5626            No             DSL                   No                   No
# 5627           Yes             DSL                  Yes                  Yes
# 5630           Yes             DSL                  Yes                  Yes
# 5631            No              No  No internet service  No internet service
# 5633            No              No  No internet service  No internet service
#
#          DeviceProtection          TechSupport         TV_Streaming  \
# 0                     Yes                   No                   No
# 1                      No                   No                  Yes
# 5                      No                   No                   No
# 6     No internet service  No internet service  No internet service
# 7     No internet service  No internet service  No internet service
# ...                   ...                  ...                  ...
# 5626                   No                   No                   No
# 5627                  Yes                  Yes                  Yes
# 5630                  Yes                  Yes                  Yes
# 5631  No internet service  No internet service  No internet service
# 5633  No internet service  No internet service  No internet service
#
#           Movie_Streaming        Contract PaperlessBilling  \
# 0                     Yes        One year               No
# 1                     Yes        Two year              Yes
# 5                      No  Month-to-month              Yes
# 6     No internet service        Two year               No
# 7     No internet service        Two year              Yes
# ...                   ...             ...              ...
# 5626                   No  Month-to-month              Yes
# 5627                  Yes        Two year              Yes
# 5630                  Yes        Two year              Yes
# 5631  No internet service  Month-to-month              Yes
# 5633  No internet service        One year               No
#
#                  Method_Payment  Charges_Month TotalCharges Churn
# 0                  Mailed check          64.85       1336.8    No
# 1     Bank transfer (automatic)          97.20      5129.45    No
# 5              Electronic check          69.55       521.35    No
# 6                  Mailed check          18.95       613.95    No
# 7       Credit card (automatic)          19.80      1414.65    No
# ...                         ...            ...          ...   ...
# 5626               Mailed check          45.25         74.2    No
# 5627               Mailed check          89.40      6376.55    No
# 5630    Credit card (automatic)          91.10       2198.3    No
# 5631           Electronic check          21.15       306.05    No
# 5633    Credit card (automatic)          19.80        457.3    No
#
# [4128 rows x 20 columns]

# %%
#Data Visualization
tenure_churn_no = df1[df1.Churn=='No'].tenure
tenure_churn_yes = df1[df1.Churn=='Yes'].tenure

plt.xlabel("tenure")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction Visualiztion")

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.hist([tenure_churn_yes, tenure_churn_no], rwidth=0.95, color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
mc_churn_no = df1[df1.Churn=='No'].Charges_Month
mc_churn_yes = df1[df1.Churn=='Yes'].Charges_Month
plt.xlabel("Monthly Charges")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction Visualization")
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]
plt.hist([mc_churn_yes, mc_churn_no], rwidth=0.95, color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
def print_unique_col_values(df):
       for column in df:
            if df[column].dtypes=='object':
                print(f'{column}: {df[column].unique()}')

# %%
print_unique_col_values(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['No' 'Yes']
# Dependents: ['Yes' 'No']
# PhoneService: ['Yes' 'No']
# MultipleLines: ['No' 'Yes' 'No phone service']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['Yes' 'No' 'No internet service']
# OnlineBackup: ['No' 'Yes' 'No internet service']
# DeviceProtection: ['Yes' 'No' 'No internet service']
# TechSupport: ['No' 'No internet service' 'Yes']
# TV_Streaming: ['No' 'Yes' 'No internet service']
# Movie_Streaming: ['Yes' 'No' 'No internet service']
# Contract: ['One year' 'Two year' 'Month-to-month']
# PaperlessBilling: ['No' 'Yes']
# Method_Payment: ['Mailed check' 'Bank transfer (automatic)' 'Electronic check'
#  'Credit card (automatic)']
# TotalCharges: ['1336.8' '5129.45' '23.45' ... '306.05' '1200.15' '457.3']
# Churn: ['No' 'Yes']

# %%
for col in df1:
    print(f'{col}: {df1[col].unique()}')
# Out:
# gender: ['Female' 'Male']
# SeniorCitizen: [0 1]
# Partner: ['No' 'Yes']
# Dependents: ['Yes' 'No']
# tenure: [21 54  1  4  7 32 72 19 10 45 40 47 36 69 71 35  3 68 42  8 46 12 26 49
#  33 31 66 58 13 57  6 59 15 27 34 18  5 39 29  2 63 20 14 56 37 24 52 43
#  11 16 50 38 23 55 48 53 70 22 28 44 65 64 60 51  9 25 61 30 17 41 67 62]
# PhoneService: ['Yes' 'No']
# MultipleLines: ['No' 'Yes' 'No phone service']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['Yes' 'No' 'No internet service']
# OnlineBackup: ['No' 'Yes' 'No internet service']
# DeviceProtection: ['Yes' 'No' 'No internet service']
# TechSupport: ['No' 'No internet service' 'Yes']
# TV_Streaming: ['No' 'Yes' 'No internet service']
# Movie_Streaming: ['Yes' 'No' 'No internet service']
# Contract: ['One year' 'Two year' 'Month-to-month']
# PaperlessBilling: ['No' 'Yes']
# Method_Payment: ['Mailed check' 'Bank transfer (automatic)' 'Electronic check'
#  'Credit card (automatic)']
# Charges_Month: [64.85 97.2  23.45 ... 59.25 35.35 21.15]
# TotalCharges: ['1336.8' '5129.45' '23.45' ... '306.05' '1200.15' '457.3']
# Churn: ['No' 'Yes']

# %%
df1['gender'].replace({'Female':1,'Male':0},inplace=True)
# Out:
# <ipython-input-24-ba153b6b6960>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['gender'].replace({'Female':1,'Male':0},inplace=True)

# %%
df1.gender.unique()
# Out:
# array([1, 0])

# %%
#One hot encoding for categorical columns
df2 = pd.get_dummies(data=df1,columns=['InternetService','Contract','Method_Payment'])
df2.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'TV_Streaming', 'Movie_Streaming',
#        'PaperlessBilling', 'Charges_Month', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'Method_Payment_Bank transfer (automatic)',
#        'Method_Payment_Credit card (automatic)',
#        'Method_Payment_Electronic check', 'Method_Payment_Mailed check'],
#       dtype='object')

# %%
df2.sample(6)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 278        1              0      No         No      58          Yes
# 5248       1              0      No         No      54           No
# 209        1              0     Yes         No      16           No
# 5294       0              0      No         No       1          Yes
# 2902       0              0     Yes        Yes       4          Yes
# 4206       0              0     Yes         No      55          Yes
#
#          MultipleLines OnlineSecurity OnlineBackup DeviceProtection  ...  \
# 278                Yes            Yes           No               No  ...
# 5248  No phone service            Yes           No               No  ...
# 209   No phone service             No           No               No  ...
# 5294                No             No           No               No  ...
# 2902                No             No           No               No  ...
# 4206                No            Yes          Yes              Yes  ...
#
#      InternetService_DSL InternetService_Fiber optic InternetService_No  \
# 278                False                        True              False
# 5248                True                       False              False
# 209                 True                       False              False
# 5294               False                        True              False
# 2902                True                       False              False
# 4206                True                       False              False
#
#      Contract_Month-to-month  Contract_One year Contract_Two year  \
# 278                     True              False             False
# 5248                   False               True             False
# 209                     True              False             False
# 5294                    True              False             False
# 2902                    True              False             False
# 4206                   False              False              True
#
#      Method_Payment_Bank transfer (automatic)  \
# 278                                      True
# 5248                                     True
# 209                                     False
# 5294                                    False
# 2902                                    False
# 4206                                    False
#
#       Method_Payment_Credit card (automatic)  Method_Payment_Electronic check  \
# 278                                    False                            False
# 5248                                   False                            False
# 209                                    False                             True
# 5294                                   False                            False
# 2902                                   False                            False
# 4206                                   False                             True
#
#       Method_Payment_Mailed check
# 278                         False
# 5248                        False
# 209                         False
# 5294                         True
# 2902                         True
# 4206                        False
#
# [6 rows x 27 columns]

# %%
df2.dtypes
# Out:
# gender                                        int64
# SeniorCitizen                                 int64
# Partner                                      object
# Dependents                                   object
# tenure                                        int64
# PhoneService                                 object
# MultipleLines                                object
# OnlineSecurity                               object
# OnlineBackup                                 object
# DeviceProtection                             object
# TechSupport                                  object
# TV_Streaming                                 object
# Movie_Streaming                              object
# PaperlessBilling                             object
# Charges_Month                               float64
# TotalCharges                                 object
# Churn                                        object
# InternetService_DSL                            bool
# InternetService_Fiber optic                    bool
# InternetService_No                             bool
# Contract_Month-to-month                        bool
# Contract_One year                              bool
# Contract_Two year                              bool
# Method_Payment_Bank transfer (automatic)       bool
# Method_Payment_Credit card (automatic)         bool
# Method_Payment_Electronic check                bool
# Method_Payment_Mailed check                    bool
# dtype: object

# %%
cols_to_scale = ['tenure','Charges_Month','TotalCharges']
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])

# %%
df2.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents    tenure PhoneService  \
# 3436       1              0     Yes         No  0.281690          Yes
# 4224       0              0      No         No  0.070423          Yes
# 4523       0              1      No         No  0.267606          Yes
# 2320       0              0      No         No  0.000000          Yes
# 1317       1              0     Yes         No  0.380282          Yes
#
#      MultipleLines       OnlineSecurity         OnlineBackup  \
# 3436           Yes                  Yes                   No
# 4224            No  No internet service  No internet service
# 4523            No                   No                   No
# 2320            No                  Yes                   No
# 1317           Yes  No internet service  No internet service
#
#          DeviceProtection  ... InternetService_DSL  \
# 3436                  Yes  ...               False
# 4224  No internet service  ...               False
# 4523                   No  ...               False
# 2320                   No  ...                True
# 1317  No internet service  ...               False
#
#      InternetService_Fiber optic InternetService_No Contract_Month-to-month  \
# 3436                        True              False                    True
# 4224                       False               True                   False
# 4523                        True              False                    True
# 2320                       False              False                    True
# 1317                       False               True                   False
#
#       Contract_One year  Contract_Two year  \
# 3436              False              False
# 4224               True              False
# 4523              False              False
# 2320              False              False
# 1317               True              False
#
#      Method_Payment_Bank transfer (automatic)  \
# 3436                                    False
# 4224                                    False
# 4523                                    False
# 2320                                    False
# 1317                                    False
#
#       Method_Payment_Credit card (automatic)  Method_Payment_Electronic check  \
# 3436                                   False                             True
# 4224                                   False                            False
# 4523                                   False                             True
# 2320                                   False                            False
# 1317                                   False                            False
#
#       Method_Payment_Mailed check
# 3436                        False
# 4224                         True
# 4523                        False
# 2320                         True
# 1317                         True
#
# [5 rows x 27 columns]

# %%
for col in df2:
    print(f'{col}: {df2[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: ['No' 'Yes']
# Dependents: ['Yes' 'No']
# tenure: [0.28169014 0.74647887 0.         0.04225352 0.08450704 0.43661972
#  1.         0.25352113 0.12676056 0.61971831 0.54929577 0.64788732
#  0.49295775 0.95774648 0.98591549 0.47887324 0.02816901 0.94366197
#  0.57746479 0.09859155 0.63380282 0.15492958 0.35211268 0.67605634
#  0.45070423 0.42253521 0.91549296 0.8028169  0.16901408 0.78873239
#  0.07042254 0.81690141 0.1971831  0.36619718 0.46478873 0.23943662
#  0.05633803 0.53521127 0.3943662  0.01408451 0.87323944 0.26760563
#  0.18309859 0.77464789 0.50704225 0.32394366 0.71830986 0.5915493
#  0.14084507 0.21126761 0.69014085 0.52112676 0.30985915 0.76056338
#  0.66197183 0.73239437 0.97183099 0.29577465 0.38028169 0.6056338
#  0.90140845 0.88732394 0.83098592 0.70422535 0.11267606 0.33802817
#  0.84507042 0.4084507  0.22535211 0.56338028 0.92957746 0.85915493]
# PhoneService: ['Yes' 'No']
# MultipleLines: ['No' 'Yes' 'No phone service']
# OnlineSecurity: ['Yes' 'No' 'No internet service']
# OnlineBackup: ['No' 'Yes' 'No internet service']
# DeviceProtection: ['Yes' 'No' 'No internet service']
# TechSupport: ['No' 'No internet service' 'Yes']
# TV_Streaming: ['No' 'Yes' 'No internet service']
# Movie_Streaming: ['Yes' 'No' 'No internet service']
# PaperlessBilling: ['No' 'Yes']
# Charges_Month: [0.46437469 0.78674639 0.05181863 ... 0.40857    0.17040359 0.02889885]
# TotalCharges: [1.52088622e-01 5.89735749e-01 5.36579737e-04 ... 3.31467805e-02
#  1.36320102e-01 5.06000462e-02]
# Churn: ['No' 'Yes']
# InternetService_DSL: [ True False]
# InternetService_Fiber optic: [False  True]
# InternetService_No: [False  True]
# Contract_Month-to-month: [False  True]
# Contract_One year: [ True False]
# Contract_Two year: [False  True]
# Method_Payment_Bank transfer (automatic): [False  True]
# Method_Payment_Credit card (automatic): [False  True]
# Method_Payment_Electronic check: [False  True]
# Method_Payment_Mailed check: [ True False]

# %%
x = df2.drop('Churn',axis='columns')
y = df2['Churn']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=5)

# %%
x_train.shape
# Out:
# (4499, 26)

# %%
x_test.shape
# Out:
# (1125, 26)

# %%
x_train[:5]
# Out:
#       gender  SeniorCitizen Partner Dependents    tenure PhoneService  \
# 1707       1              0      No         No  0.521127          Yes
# 1373       1              0      No         No  0.464789          Yes
# 1311       1              0     Yes        Yes  0.225352          Yes
# 151        1              0     Yes        Yes  0.760563          Yes
# 2456       1              0     Yes        Yes  0.267606          Yes
#
#      MultipleLines       OnlineSecurity         OnlineBackup  \
# 1707           Yes  No internet service  No internet service
# 1373           Yes                  Yes                  Yes
# 1311            No                  Yes                  Yes
# 151             No                   No                   No
# 2456           Yes                   No                   No
#
#          DeviceProtection  ... InternetService_DSL  \
# 1707  No internet service  ...               False
# 1373                   No  ...                True
# 1311                   No  ...                True
# 151                    No  ...               False
# 2456                  Yes  ...               False
#
#      InternetService_Fiber optic InternetService_No Contract_Month-to-month  \
# 1707                       False               True                   False
# 1373                       False              False                   False
# 1311                       False              False                    True
# 151                         True              False                   False
# 2456                        True              False                    True
#
#       Contract_One year  Contract_Two year  \
# 1707               True              False
# 1373               True              False
# 1311              False              False
# 151               False               True
# 2456              False              False
#
#       Method_Payment_Bank transfer (automatic)  \
# 1707                                     False
# 1373                                     False
# 1311                                     False
# 151                                      False
# 2456                                      True
#
#       Method_Payment_Credit card (automatic)  Method_Payment_Electronic check  \
# 1707                                   False                             True
# 1373                                   False                            False
# 1311                                   False                            False
# 151                                     True                            False
# 2456                                   False                            False
#
#       Method_Payment_Mailed check
# 1707                        False
# 1373                         True
# 1311                         True
# 151                         False
# 2456                        False
#
# [5 rows x 26 columns]

# %%
len(x_train.columns)
# Out:
# 26

# %%
import tensorflow as tf
from tensorflow import keras
model = keras.Sequential([
    keras.layers.Dense(20, input_shape=(26,), activation='relu'),
    keras.layers.Dense(1, activation='sigmoid'),
])
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
from sklearn.metrics import classification_report
y_true = [0, 1, 2, 2, 2]
y_pred = [0, 0, 2, 2, 1]
report = classification_report(y_true, y_pred, zero_division=1)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#            2       1.00      0.67      0.80         3
#
#     accuracy                           0.60         5
#    macro avg       0.50      0.56      0.49         5
# weighted avg       0.70      0.60      0.61         5

# %%
import numpy as np
import tensorflow as tf
import seaborn as sn
import matplotlib.pyplot as plt
# Example data
y_test = np.array([0, 1, 2, 2, 2])  # True labels
y_pred = np.array([0, 0, 2, 2, 1])  # Predicted labels
# Ensure y_test and y_pred are of the same shape
assert y_test.shape == y_pred.shape, "Shapes of y_test and y_pred must match"
# Calculate the confusion matrix
cm = tf.math.confusion_matrix(labels=y_test, predictions=y_pred)
# Plot the confusion matrix
plt.figure(figsize=(10, 7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
y_test.shape
# Out:
# (5,)

# %%
round((862+229)/(862+229+137+179),2)

round(1/1+1+0,3)
# Out:
# 2.0
